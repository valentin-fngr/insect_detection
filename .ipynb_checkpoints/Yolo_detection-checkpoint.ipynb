# %%
import numpy as np 
import tensorflow as tf 
import matplotlib.pyplot as plt 
import os
import matplotlib.patches as patches
import cv2

# %%
strategy = tf.distribute.MirroredStrategy()
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)

# %%
labels = ["Coleoptera", "Diptera", "Hemiptera", "Hymenoptera", "Lepidoptera", "Odonata"]
print(len(labels))
def get_label(id): 
    return labels[id]

nb_boxes = 2
nb_classes = len(labels)
# Out:
# 6

# %% [markdown]
# ### Reading the tf record files

# %%
def draw_boxes_cv2(image, boxes, categories):
    image = np.array(image, dtype=np.uint8)
    boxes = np.array(boxes, dtype=np.int32)
    categories = np.array(categories)
    for _box, _cls in zip(boxes, categories):
        text = _cls
        char_len = len(text) * 9
        text_orig = (_box[0] + 5, _box[1] - 6)
        text_bg_xy1 = (_box[0], _box[1] - 20)
        text_bg_xy2 = (_box[0] + char_len, _box[1])
        image = cv2.rectangle(image, text_bg_xy1, text_bg_xy2, [255, 252, 150],
                              -1)
        image = cv2.putText(image,
                            text,
                            text_orig,
                            cv2.FONT_HERSHEY_COMPLEX_SMALL,
                            .6, [0, 0, 0],
                            5,
                            lineType=cv2.LINE_AA)
        image = cv2.putText(image,
                            text,
                            text_orig,
                            cv2.FONT_HERSHEY_COMPLEX_SMALL,
                            .6, [255, 255, 255],
                            1,
                            lineType=cv2.LINE_AA)
        image = cv2.rectangle(image, (_box[0], _box[1]), (_box[2], _box[3]),
                              [30, 15, 30], 2)
    return image

# %%
tf_records_path = os.path.join(os.getcwd(), "dataset/records")
tf_records = [os.path.join(tf_records_path, path) for path in os.listdir(tf_records_path) if "Diptera" in path]
print(f"found {len(tf_records)} tf records files")
# Out:
# found 11 tf records files

# %%
def from_hwlt_to_xyxy(bboxes): 
    """
        convert a bboxs with format whlt to xmin ymin xmax ymax format
        Input: 
            a (n,4) tensor
    """
    print("before converting", bboxes)
    return tf.stack([
        bboxes[:,3], 
        bboxes[:,2], 
        bboxes[:,3] + bboxes[:,1],
        bboxes[:,2] + bboxes[:,0]
    ], axis=-1)

# %%
image_feature_description = {
    "image/encoded" : tf.io.FixedLenFeature([], tf.string),
    "image/obj/heights": tf.io.VarLenFeature(tf.float32),
    "image/obj/widths": tf.io.VarLenFeature(tf.float32),
    "image/obj/lefts": tf.io.VarLenFeature(tf.float32),
    "image/obj/tops": tf.io.VarLenFeature(tf.float32),
    "image/obj/class_id": tf.io.VarLenFeature(tf.int64)
}



def parse_example(example_proto): 
    """
        deserialize a raw record
    """
    example =  tf.io.parse_single_example(example_proto, image_feature_description)
    image = tf.image.decode_image(example["image/encoded"], channels=3)
    image.set_shape([None, None, 3])
    bboxes = tf.stack([
     tf.sparse.to_dense(example["image/obj/heights"]), 
     tf.sparse.to_dense(example["image/obj/widths"]), 
     tf.sparse.to_dense(example["image/obj/lefts"]), # be careful ! inverted with top !
     tf.sparse.to_dense(example["image/obj/tops"]) # be careful ! inverted with left ! 
    ], axis=-1)
    bboxes = from_hwlt_to_xyxy(bboxes)
    # resizing all images
        
    
    label = tf.sparse.to_dense(example["image/obj/class_id"])
    return image, bboxes, label

# %% [markdown]
# ### functions to manipulate bounding boxes

# %%
def from_hwlt_to_xyxy(bboxes): 
    """
        convert a bboxs with format whlt to xmin ymin xmax ymax format
        Input: 
            a (n,4) tensor
    """
    return tf.stack([
        bboxes[:,3], 
        bboxes[:,2], 
        bboxes[:,3] + bboxes[:,1],
        bboxes[:,2] + bboxes[:,0]
    ], axis=-1)

def from_xyxy_to_xywh(bboxes): 
    x = (1 + bboxes[..., 0] + bboxes[..., 2]) / 2.0
    y = (1 + bboxes[..., 1] + bboxes[..., 3]) / 2.0
    w = 1 + bboxes[..., 2] - bboxes[..., 0]
    h = 1 + bboxes[..., 3] - bboxes[..., 1]
    return tf.stack([x, y, w, h], axis=-1)


def from_xywh_to_xyxy(bboxes): 
    x1 = bboxes[..., 0] - bboxes[..., 2] / 2.0
    y1 = bboxes[..., 1] - bboxes[..., 3] / 2.0
    x2 = (bboxes[..., 0] + bboxes[..., 2] / 2.0) - 1
    y2 = (bboxes[..., 1] + bboxes[..., 3] / 2.0) - 1
    
    return tf.stack([x1, y1, x2, y2], axis=-1)

# %%
# dataset_size = 10000

# %%
def encode_label(image, bboxes, cls): 

    """
        given an bboxes and labels
        create a Yolo formatted label of size(SxS, K + 5*nb_boxes) 
        # Important : 
            the width and heights of the bboxes in the target tensor are normalized regarding the IMAGE WIDTH/HEIGHT
            the center coordinates (x,y) are normalized regarding the cell dimensions!
        Argument: 
            bboxes : a (n,4) tensor of xyxy coordinates
            label : a (n,) tensor 
    """
    
    label_shape = (448//64, 448//64, nb_boxes + nb_boxes*4 + nb_classes) # rank 3 tensor
    
    nb_items = tf.shape(bboxes)[0]
    
    # zeros output
    label = tf.zeros(label_shape)
    
    # convert bboxes to xywh
    xywh_boxes = from_xyxy_to_xywh(bboxes)
    centers = xywh_boxes[:,:2] 
    wh = xywh_boxes[:,2:]
    
    # get cell coordinates and normalize coordinates
    grid_offset = tf.math.floordiv(centers, 64.0) # (nb_boxes,2) -> 2 : xy cell pos
    normalized_centers = centers / 64.0 - grid_offset
    normalized_wh = wh / 448 
    normalized_bboxes = tf.concat([normalized_centers, normalized_wh], axis=-1) # (nb_items, 4) # FIXED AXIS 
    # one hot encoding 
    one_hot = tf.one_hot(tf.cast(cls, tf.int32), nb_classes, dtype=tf.float32) # (nb_items, 2)
    print("label", cls)

    # create vector for each cell
    confidence = tf.ones([nb_items, 1], dtype=tf.float32) # (nb_items, 1)
    # concat everything
    # (nb_items, 12)
    vectors = tf.concat([confidence, confidence, normalized_bboxes, normalized_bboxes, one_hot], axis=1)
    # needs to be rank 3
    vectors = tf.reshape(vectors, [1, nb_items, nb_boxes + nb_boxes*4 + nb_classes])
    
    # find indices 
    indices = tf.stack([grid_offset[:,1], grid_offset[:,0]], axis=-1) 
    indices = tf.cast(indices, dtype=tf.int32)
    indices = tf.cast(tf.reshape(indices, [1, nb_items, 2]), tf.int32) 
    
    label = tf.tensor_scatter_nd_update(label, indices, vectors)
    return image, label

# %%
def parse_and_create_label(example_proto): 
    image, bboxes, cls = parse_example(example_proto)
    image = tf.cast(image, dtype=tf.float32) / 255.0 
    image, label = encode_label(image, bboxes, cls)
    return image, label

def build_dataset(dataset, batch_size):
    #dataset = tfrecords.interleave(
    #    tf.data.TFRecordDataset,
    #    cycle_length=8,
    #    block_length=32,
    #    num_parallel_calls=tf.data.experimental.AUTOTUNE)
    dataset = dataset.shuffle(512)
    dataset = dataset.map(parse_and_create_label,
                          num_parallel_calls=tf.data.experimental.AUTOTUNE)
    print("dataset",dataset)
    dataset = dataset.batch(batch_size)
    dataset = dataset.repeat()
    dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
    return dataset

# %%
# opening the raw dataset out of the tf records files
records =  tf.data.TFRecordDataset(tf_records)
dataset = build_dataset(records, 8)
print(dataset)
# Out:
# label Tensor("SparseToDense_4:0", shape=(None,), dtype=int64)
# dataset <ParallelMapDataset shapes: ((None, None, 3), (7, 7, 16)), types: (tf.float32, tf.float32)>
# <PrefetchDataset shapes: ((None, None, None, 3), (None, 7, 7, 16)), types: (tf.float32, tf.float32)>

# %%
def validate_dataset(filenames, reader_opts=None):
    """
    Attempt to iterate over every record in the supplied iterable of TFRecord filenames
    :param filenames: iterable of filenames to read
    :param reader_opts: (optional) tf.python_io.TFRecordOptions to use when constructing the record iterator
    """
    i = 0
    for fname in filenames:

        record_iterator =  tf.compat.v1.io.tf_record_iterator(path=fname, options=reader_opts)
        try:
            for _ in record_iterator:
                i += 1
        except Exception as e:
            print('error in {} at record {}'.format(fname, i))
            print(e)
            
validate_dataset(tf_records)
# Out:
# WARNING:tensorflow:From <ipython-input-13-8694d02dc3d1>:10: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`

# %% [markdown]
# ### Visualizing the training data

# %%
def visualize_example(image, bboxes, label):
    
    fig, ax = plt.subplots(figsize=(5,5))
    
    
    boxes = bboxes 
    for bbox in boxes: 
        rect = patches.Rectangle((bbox[0], bbox[1]), bbox[2] - bbox[0] , bbox[3] - bbox[1], linewidth=1, edgecolor='r', facecolor='none')
        ax.add_patch(rect)
    
    plt.imshow(image) 
    plt.title(get_label(label.numpy()[0]))
    plt.show()

# %% [markdown]
# ### Model hyperparameters

# %%
width = 448 
height = 448
S = 7
cell_size = (width/ S, height/ S)
batch_size = 32
nb_boxes = 2
nb_classes = len(labels)


dataset=dataset.take(8000)

# %%
train_dataset = dataset.take(6400) 
test_dataset = dataset.skip(6400)

# %%
def conv_block(tensor, filters, kernel_size, stride):
    x = tf.keras.layers.Conv2D(filters=filters,
                               kernel_size=kernel_size,
                               strides=stride,
                               padding='same',
                               use_bias=False,
                               kernel_initializer='he_normal')(tensor)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.LeakyReLU(0.1)(x)
    return x


def build_model(H, W, num_classes):
    stride = 64
    grid_shape = [H // cell_size[0], W // cell_size[1]]

    image_input = tf.keras.Input(shape=[H, W, 3], name='image_input')
    x = conv_block(image_input, filters=16, kernel_size=3, stride=1)
    x = tf.keras.layers.MaxPool2D(pool_size=2)(x)
    x = conv_block(x, filters=32, kernel_size=3, stride=1)
    x = tf.keras.layers.MaxPool2D(pool_size=2)(x)
    x = conv_block(x, filters=64, kernel_size=3, stride=1)
    x = tf.keras.layers.MaxPool2D(pool_size=2)(x)
    x = conv_block(x, filters=128, kernel_size=3, stride=1)
    x = tf.keras.layers.MaxPool2D(pool_size=2)(x)
    x = conv_block(x, filters=256, kernel_size=3, stride=1)
    x = tf.keras.layers.MaxPool2D(pool_size=2)(x)
    x = conv_block(x, filters=512, kernel_size=3, stride=1)
    x = tf.keras.layers.MaxPool2D(pool_size=2)(x)
    x = conv_block(x, filters=1024, kernel_size=3, stride=1)
    x = conv_block(x, filters=1024, kernel_size=3, stride=1)
    x = conv_block(x, filters=1024, kernel_size=3, stride=1)
    # Fully convolutional
    predictions = tf.keras.layers.Conv2D(filters=(2 * 5 + num_classes),
                                         kernel_size=1)(x)
    return tf.keras.Model(inputs=[image_input],
                          outputs=[predictions],
                          name='yolo')

# %%
def compute_iou(boxes1, boxes2): 
    """
        given two corner coordinates formatted bbox, return the IOU between the gt and the NBOXES other bbox 
        in a cell
    """
    
    boxes1_t = from_xywh_to_xyxy(boxes1)
    boxes2_t = from_xywh_to_xyxy(boxes2)

    lu = tf.maximum(boxes1_t[:, :, :, :, :2], boxes2_t[:, :, :, :, :2])
    rd = tf.minimum(boxes1_t[:, :, :, :, 2:], boxes2_t[:, :, :, :, 2:])

    intersection = tf.maximum(0.0, rd - lu)
    inter_square = intersection[:, :, :, :, 0] * intersection[:, :, :, :, 1]

    square1 = boxes1[:, :, :, :, 2] * boxes1[:, :, :, :, 3]
    square2 = boxes2[:, :, :, :, 2] * boxes2[:, :, :, :, 3]

    union_square = tf.maximum((square1 + square2) - inter_square, 1e-10)
    return tf.clip_by_value(inter_square / union_square, 0.0, 1.0)

# %%
class DecodePrediction(tf.keras.layers.Layer): 
    
    def __init__(self, **kwargs): 
        super(DecodePrediction, self).__init__(**kwargs)
        self.meshgrid = self._build_meshgrid() 
        
    def _build_meshgrid(self): 
        meshgrid = tf.stack(tf.meshgrid(tf.range(S),tf.range(S)),axis=-1)
        meshgrid = tf.reshape(meshgrid,shape=[1, S, S,  1, 2])
        meshgrid = tf.tile(meshgrid, multiples=[1, 1, 1, 2, 1])
        meshgrid = tf.cast(meshgrid, dtype=tf.float32)
        return meshgrid
        
    def call(self, input_tensor, square_wh, training=True): 
        # extract boxes 
        print(input_tensor.shape)
        coordinates = input_tensor[:,:,:,nb_boxes:nb_boxes*4 + nb_boxes] 
        normalized_coordinates = tf.reshape(coordinates, [-1, 7, 7, nb_boxes, 4])
        normalized_centers = normalized_coordinates[:,:,:,:,:2] # (bs,s, s, 2, 2) 
        normalized_wh = normalized_coordinates[:,:,:,:,2:] # (bs,s, s, 2, 2)

        cls_pred = input_tensor[:,:,:,2*4 + 2:]
        object_scores = input_tensor[:,:,:,:nb_boxes]

        # denorm 
        denormalized_centers = (normalized_centers + self.meshgrid) * tf.cast(64.0, dtype=tf.float32)  

        if square_wh: 
            normalized_wh = tf.square(normalized_wh)
        denormalized_wh = normalized_wh * 448

        denormalized_bbox = tf.concat([denormalized_centers, denormalized_wh], axis=-1)
        # return denorm bbox during training in order to compute the iou
        if training: 
            return denormalized_bbox
        
        denormalized_bbox = tf.reshape(denormalized_bbox, [-1, 4])
        print(cls_pred.shape)
        cls_ids = tf.argmax(cls_pred, axis=-1)
        cls_ids = tf.tile(tf.expand_dims(cls_ids, axis=-1),
                          multiples=[1, 1, 1, 2])
        cls_ids = tf.reshape(cls_ids, [-1])
        cls_scores = tf.reduce_max(cls_pred, axis=-1)
        cls_scores = tf.tile(tf.expand_dims(cls_scores, axis=-1),
                             multiples=[1, 1, 1, 2])

        class_probs = cls_scores * object_scores
        class_probs = tf.reshape(class_probs, [-1])

        denormalized_boxes_x1y1x2y2 = from_xywh_to_xyxy(denormalized_bbox)
        indices = tf.image.non_max_suppression(denormalized_boxes_x1y1x2y2,
                                               class_probs, 100,
                                               0.5,
                                               0.5)

        nms_boxes = tf.gather(denormalized_boxes_x1y1x2y2,
                              indices,
                              name='boxes')
        nms_class_probs = tf.gather(class_probs, indices, name='scores')
        nms_cls_ids = tf.gather(cls_ids, indices, name='class_ids')
        return {
            'boxes': nms_boxes,
            'class_ids': nms_cls_ids,
            'scores': nms_class_probs
        }


class YoloLoss(tf.keras.losses.Loss): 
    
    def __init__(self): 
        super(YoloLoss, self).__init__()
        self.decoder = DecodePrediction()
    
    def call(self,y_true, y_pred):
        """
            compute the yolo loss 
            Argument: 
                y_true : a (BS,S,S,5*nb_boxes + 6) tensor 
                y_pred : a (BS,S,S,5*nb_boxes + 6) tensor
        """
        
        print("y_true", y_true.shape)
        print("y_pred", y_pred.shape)

        true_conf = y_true[:,:,:,:1] 
        true_bboxes = y_true[:,:,:,nb_boxes:nb_boxes*4 + nb_boxes] 
        true_bboxes = tf.reshape(true_bboxes, [-1, S, S ,2, 4]) 
        true_classes = y_true[:,:,:,nb_boxes*4 + nb_boxes:]

        pred_conf = y_pred[:,:,:,:nb_boxes] # (bs, s, s, 2)
        pred_bboxes = y_pred[:,:,:,nb_boxes:nb_boxes*4 + nb_boxes] 
        pred_bboxes = tf.reshape(pred_bboxes, [-1, S, S, 2, 4]) # (-1, s, s, 2, 4)
        pred_classes = y_pred[:,:,:,nb_boxes*4 + nb_boxes:]

        true_centers = true_bboxes[:,:,:,:,:2] 
        pred_centers = pred_bboxes[:,:,:,:,:2] 

        true_wh = tf.sqrt(true_bboxes[:,:,:,:,2:]) 
        pred_wh = pred_bboxes[:,:,:,:,2:] # we might have predicted negative wh so we can't use sqrt here
        # we are asking the model to predict sqrt(wh) not wh !

        # get denormalized boxes
        denorm_true_coord = self.decoder(y_true, training=True, square_wh=False)
        denorm_pred_coord = self.decoder(y_pred, training=True, square_wh=True) # we need to square wh because we are learning sqrt(wh), not wh


        # compute iou between y_true, y_pred 
        iou = compute_iou(denorm_true_coord, denorm_pred_coord) # (bs, s, s, 2) 
        max_iou = tf.reduce_max(iou, axis=-1, keepdims=True) # (bs, s, s, 2)
        # boxes containing object or not
        object_mask = tf.cast(tf.equal(true_conf, 1.0), dtype=tf.float32)  
        # boxes responsible for detections 
        predictor = tf.cast(tf.equal(iou, max_iou), dtype=tf.float32) * object_mask # (bs, s, s, 2) 
        predictor_loc = tf.tile(tf.expand_dims(predictor, axis=-1), [1, 1, 1, 1, 2]) # (bs, s, s, 2, 2) 
        noobj_mask = tf.ones_like(predictor) - predictor # (bs, s, s, 2) # updated

        xy_loss = tf.reduce_sum(predictor_loc*tf.square(true_centers - pred_centers), axis=[1,2,3,4])
        wh_loss = tf.reduce_sum(predictor_loc*tf.square(true_wh - pred_wh), axis=[1,2,3,4])
        object_loss = tf.reduce_sum(predictor*tf.square(iou - pred_conf), axis=[1,2,3])
        noobj_loss = tf.reduce_sum(noobj_mask*tf.square(pred_conf), axis=[1,2,3])
        print(object_mask.shape)
        cls_loss = tf.reduce_sum(object_mask * tf.square(true_classes - pred_classes), axis=[1,2,3]) 

        print("LOSSSSS ",cls_loss)
        return 5.0 * xy_loss + 5.0 * wh_loss + object_loss + 0.5*noobj_loss + cls_loss

# %%
print(len(labels))
# Out:
# 6

# %%
yolov1 = build_model(448,448, len(labels))
yolov1.summary()
# Out:
# Model: "yolo"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# image_input (InputLayer)     [(None, 448, 448, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 448, 448, 16)      432
# _________________________________________________________________
# batch_normalization (BatchNo (None, 448, 448, 16)      64
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 448, 448, 16)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 224, 224, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 224, 224, 32)      4608
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 224, 224, 32)      128
# ...

# %%
train_dataset = train_dataset.apply(tf.data.experimental.ignore_errors())
test_dataset = test_dataset.apply(tf.data.experimental.ignore_errors())

# %%
def learning_rate_strategy(strategy, init_lr=0.001, decay_rate=0.75): 
    
    
    def step_2(epoch, lr): 
        if epoch > 30 and epoch < 60:
            return 0.0002
        elif epoch > 60: 
            return 0.00004
        return lr
    
        
    
    d = {
        "step2": step_2,
    }
    
    return d[strategy]

# %%
def training(strat=None, lr=0.00004): 
    loss = YoloLoss()
    yolov1 = build_model(448,448, len(labels))
    #yolov1 = tf.keras.models.load_model("new_distr_sanity_coleoptera_best_yolov_lr=0.0001_batch_size=16.h5", compile=False)

    optimizer = tf.keras.optimizers.Adam(lr)
    log_dir = "logs/fit/" + f"best_lr={lr}_batch_size={batch_size}full.h5"
    
    
    callbacks = [
        tf.keras.callbacks.ModelCheckpoint(f'best_lr={lr}_batch_size={batch_size}full.h5', save_best_only=True, verbose=1),
        tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1), 
        tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=6)
    ]
    
    if strat: 
        scheduler = learning_rate_strategy(strat,lr)
        callbacks.append(tf.keras.callbacks.LearningRateScheduler(scheduler, verbose=1))


    yolov1.compile(
        optimizer=optimizer, 
        loss=loss
    )

    yolov1.fit(
        train_dataset, 
        validation_data=test_dataset,
        epochs=50, 
        callbacks=callbacks, 
    )

# %%
labels
# Out:
# ['Coleoptera', 'Diptera', 'Hemiptera', 'Hymenoptera', 'Lepidoptera', 'Odonata']

# %%
# training 
training()
# Out:
# Epoch 1/50
# y_true (None, 7, 7, 16)
# y_pred (None, 7, 7, 16)
# (None, 7, 7, 16)
# (None, 7, 7, 16)
# (None, 7, 7, 1)
# LOSSSSS  Tensor("YoloLoss/Sum_4:0", shape=(None,), dtype=float32)
# y_true (None, 7, 7, 16)
# y_pred (None, 7, 7, 16)
# (None, 7, 7, 16)
# (None, 7, 7, 16)
# (None, 7, 7, 1)
# LOSSSSS  Tensor("YoloLoss/Sum_4:0", shape=(None,), dtype=float32)
#    6400/Unknown - 699s 108ms/step - loss: 2.0604y_true (None, 7, 7, 16)
# y_pred (None, 7, 7, 16)
# (None, 7, 7, 16)
# (None, 7, 7, 16)
# (None, 7, 7, 1)
# LOSSSSS  Tensor("YoloLoss/Sum_4:0", shape=(None,), dtype=float32)
# 6400/6400 [==============================] - 831s 129ms/step - loss: 2.0604 - val_loss: 0.6655
#
# Epoch 00001: val_loss improved from inf to 0.66553, saving model to best_lr=4e-05_batch_size=32full.h5
# Epoch 2/50
# 6400/6400 [==============================] - 827s 129ms/step - loss: 0.4519 - val_loss: 0.2673
#
# ...

# %%
# inference 
def yolo_predict(): 
    
    inputs = tf.keras.Input((448,448,3))
    preds = yolov1(inputs)
    preds = DecodePrediction()(preds, square_wh=True, training=False)
    inference_model = tf.keras.Model(inputs=[inputs], outputs=preds)
    
    return inference_model

# %%
inference_model = yolo_predict()
# Out:
# (None, 7, 7, 16)
# (None, 7, 7, 6)

# %%
for images, _ in dataset.take(3):
    plt.figure(figsize=(8, 8))
    for i in range(images.shape[0]):
        image = images[i]
        prediction = inference_model(image[None, ...])
        boxes, classes, scores = prediction['boxes'], prediction[
            'class_ids'], prediction['scores']
        print(boxes)
        # rescale the image before visualizing it
        viz_image = draw_boxes_cv2((image*255.0), boxes, [str(x) for x in classes])
        plt.imshow(viz_image)
        break
    break
# Out:
# (1, 7, 7, 16)
# (1, 7, 7, 6)
# tf.Tensor(
# [[ -871.0104       42.174805   1304.0819      571.04865  ]
#  [ -467.94708     -42.268555    721.5159      643.07715  ]
#  [   -5.0596924  -550.947       402.66736    1101.5513   ]
#  [-1225.7714     -473.3074     1534.3712     1169.1193   ]
#  [ -195.47784    -333.23245     651.1318      783.19226  ]
#  [-1691.824      -208.22354    1853.4414      595.90173  ]
#  [  127.18869     276.1572      548.3165      328.09952  ]
#  [-1763.7551       48.47072    1756.9072      150.42964  ]
#  [ -974.8595      339.9793      911.27563     438.54327  ]
#  [  282.73904     124.82782     335.37735     384.9004   ]
#  [ -826.3453      216.29926     642.1951      405.73657  ]
#  [ -783.66516     133.2945      749.89026     132.88818  ]
#  [  187.40025      87.67578     381.96143     292.43475  ]], shape=(13, 4), dtype=float32)

# %%
test_sample = list(test_dataset.take(1).as_numpy_iterator())[0]

# %%
test_images = test_sample[0]
test_image = np.expand_dims(test_images[0], axis=0)

# %%
predict_and_visualize(test_image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-483866c9db1d> in <module>
# ----> 1 predict_and_visualize(test_image)
#
# NameError: name 'predict_and_visualize' is not defined
